# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv')
## to give index inttially while uploading the data, the following line is used
#df = pd.read_csv('survey_results_public.csv', index_col='Country')

# %%
#df

# %%
df.shape
# Out:
# (88883, 85)

# %%
#df.info()#gives datatype and count of not null columns

# %% [markdown]
# #### the following helps in showing all the columns without contracting

# %%
pd.set_option('display.max_columns',85)

# %%
#df

# %% [markdown]
# #### the above columns are described in survey_results_schema file

# %%
schema_df = pd.read_csv('survey_results_schema.csv')

# %%
pd.set_option('display.max_rows',85)
#schema_df

# %% [markdown]
# ### Series: A series is a collection of rows of a single column
# ### Dataframe: it is a container of these series. (if more than 1 series is present it is called dataframe)

# %%
#df.columns

# %% [markdown]
# ### Unlike accessing the columns of a dataframe u can use 'loc' and 'iloc' to access rows of a dataframe. loc is used to access the rows using integers and columns whereas iloc is used to access the rows using integers since the name iloc itself says integer_location

# %%
df.loc[[0,1],'MainBranch']
# Out:
# 0    I am a student who is learning to code
# 1    I am a student who is learning to code
# Name: MainBranch, dtype: object

# %%
df.iloc[[0,4],2]
# Out:
# 0    Yes
# 4    Yes
# Name: Hobbyist, dtype: object

# %% [markdown]
# #### slicing of rows

# %%
df.iloc[0:3,2]
# Out:
# 0    Yes
# 1     No
# 2    Yes
# Name: Hobbyist, dtype: object

# %%
#df.loc[0:3,'MainBranch':'Ethnicity']

# %% [markdown]
# ### The following helps to set the index to a dataframe

# %%
df.set_index('Country',inplace = True)

# %%
#df.loc['United Kingdom']

# %% [markdown]
# #### To remove the index

# %%
df.reset_index(inplace = True)

# %%
schema_df = pd.read_csv('survey_results_schema.csv', index_col = 'Column')

# %% [markdown]
# #### To sort the dataframe based on index

# %%
#df.sort_values('Country')

# %% [markdown]
# ### Filtering the data

# %%
filt = (df['Country']=='United Kingdom')
df[filt]
#OR
df[(df['Country']=='United Kingdom')]
#OR using loc u can also get the specific columns of filtered rows
df.loc[filt,'Student']
# In order to filter based on two conditions unlike in python u need to use '&' for 'and' and '|' for 'or'
#df.loc[((df['Country']=='United Kingdom') & (df['Hobbyist']=='Yes')),'OpenSourcer'] # filtering based on two conditions and getting the opensourcer column
# In order to filter the reverse of a given condition use '~' symbol before the condition
#df.loc[~((df['Country']=='United Kingdom') & (df['Hobbyist']=='Yes')),'OpenSourcer']
# If u want to filter based on multiple conditions u need to use 'isin' method
##countries = ['United Kingdom','India','United States','Germany','Canada']
#filt = df['Country'].isin(countries)
#df.loc[filt,'Country']
filt = ((df['LanguageWorkedWith'].str.contains('Python',na = True))& ~(df['LanguageWorkedWith'].str.contains('NaN',na=True)))
#filt
df.loc[filt,'Country']
# Out:
# 0                United Kingdom
# 1        Bosnia and Herzegovina
# 3                 United States
# 4                       Ukraine
# 7                         India
#                   ...
# 88854            United Kingdom
# 88860                    Brazil
# 88865               Switzerland
# 88872            Czech Republic
# 88876                     Spain
# Name: Country, Length: 36443, dtype: object

# %%
#df.loc[filt,'Respondent']

# %% [markdown]
# ### Updating the columns

# %%
#df.columns = ['Union','ID',.........] similarly u need to update names for all column names
# To change names back to original names:
df.rename(columns={'Mainbranch':'subbranch'},inplace = True)#similarly u need to update names for all column names
# To convert into upper case

#df.columns = [x.upper() for x in df.columns]
#df.columns = [x.title() for x in df.columns]

# To replace any spaces or any specialcharacters with something else
##df.columns = df.columns.str.replace('Open','Close')
#df.columns = df.columns.str.replace('close','Open')

# %% [markdown]
# ### To overwrite the data in particular cell

# %%
filt = df['Country'] =='United Kingdom'
df.loc[filt,'Student'] = 'Yes'

# %% [markdown]
# #### To convert the data of specific column to lowercase or uppercase or title case etc.

# %%
#df['Country']=df['Country'].str.lower()
#OR by using apply() method
def update_hobbyist(hobbyist):
    return hobbyist.upper()
df['Hobbyist'] = df['Hobbyist'].apply(update_hobbyist)
#OR 
df['Hobbyist'] = df['Hobbyist'].apply(lambda x: x.title())
#df

# %%
# to find the length of the element present in a cell
df['Hobbyist'].apply(len)
#df.applymap(len)
#df.applymap(str.lower)
# Out:
# 0        3
# 1        2
# 2        3
# 3        2
# 4        3
#         ..
# 88878    3
# 88879    2
# 88880    2
# 88881    2
# 88882    3
# Name: Hobbyist, Length: 88883, dtype: int64

# %%
#df.info()

# %% [markdown]
# #### To combine the data of two columns or adding new column similarly

# %%
df['newcolumn'] = df['Country']+' '+df['MainBranch']
#df

# %% [markdown]
# #### Adding new row

# %%
#df.append(schema_df['QuestionText'],ignore_index=True)

# %%
#dropping a column
#df.drop(columns=['QuestionText'],inplace=True)

# %%
#dropping rows based on a condition
filt = df['Country']=='United Kingdom'
#df.drop(index = df[filt].index)

# %% [markdown]
# ### sorting the rows and columns

# %%
#sorting the rows
df.sort_values(['Country','Respondent'],ascending = False)
# you can also use a list of columns in place of country to sort simultaneously
#df.sort_values(by = ['Country','Hobbyist','Respondent'],ascending = [False,True,False])# the sorting order is first satisfied for the first variable

# sorting using index
#df.sort_index()
# Out:
#         Country  Respondent  \
# 83632  Zimbabwe       84155
# 83328  Zimbabwe       83850
# 82241  Zimbabwe       82752
# 77054  Zimbabwe       77533
# 76118  Zimbabwe       76594
# ...         ...         ...
# 88357       NaN        6575
# 88354       NaN        5688
# 88351       NaN        4587
# 88349       NaN        4271
# 88339       NaN        2679
#
#                                               MainBranch Hobbyist  \
# 83632  I am not primarily a developer, but I write co...      Yes
# 83328                     I am a developer by profession       No
# 82241                     I am a developer by profession      Yes
# 77054                        I code primarily as a hobby      Yes
# 76118                     I am a developer by profession       No
# ...                                                  ...      ...
# 88357                                                NaN       No
# 88354                                                NaN       No
# ...

# %%
#sorting n largest values
#gives only these values
df['ConvertedComp'].nlargest(10)# similarly for smallest values
# Out:
# 57      2000000.0
# 101     2000000.0
# 164     2000000.0
# 434     2000000.0
# 450     2000000.0
# 489     2000000.0
# 537     2000000.0
# 767     2000000.0
# 786     2000000.0
# 1228    2000000.0
# Name: ConvertedComp, dtype: float64

# %%
#gives all the dataset based on sorting condition
#df.nlargest(10,'ConvertedComp')

# %%
#df['ConvertedComp'].value_counts() gives how many times a values is repeating
#df['ConvertedComp'].describe()
#df['ConvertedComp'].mean()
#df['ConvertedComp'].count()
#df['ConvertedComp'].value_counts(normalize=True) gives in percentage of each element

# %% [markdown]
# ### grouping and aggregating

# %%
country_grp = df.groupby(['Country'])
#country_grp.get_group('India')
#country_grp['Respondent'].value_counts().head(50)#for each country how many people are using the each social media app
#country_grp['SocialMedia'].value_counts().loc['India']
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
#country_grp['SocialMedia']
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
#aggregating the data
#country_grp['ConvertedComp'].agg(['mean','median'])
#country_grp['ConvertedComp'].agg(['mean','median']).loc['Canada']

# %%
filt = df['Country'] == 'United States'
#df.loc[filt,'SocialMedia'].value_counts()

# %%
#creating a seperate dataframe using columns of main dataframe
python_df = pd.concat([df['Country'],df['SocialMedia']],axis = 'columns')

# %%
python_df
# Out:
#                       Country SocialMedia
# 0              United Kingdom     Twitter
# 1      Bosnia and Herzegovina   Instagram
# 2                    Thailand      Reddit
# 3               United States      Reddit
# 4                     Ukraine    Facebook
# ...                       ...         ...
# 88878                  Canada     YouTube
# 88879                     NaN         NaN
# 88880                     NaN         NaN
# 88881                     NaN         NaN
# 88882                   Spain    WhatsApp
#
# [88883 rows x 2 columns]

# %%
#import pandas as pd
#import numpy as np

# %%
#people = {'first': ['corey','jane','john','chris',np.nan,None,'NA'],
          #'last':['schafer','doe','doe','schafer',np.nan,np.nan,'missing'],
         # 'email':['coreyschafer@gmail.com','janedoe@gmail.com','johndoe@gmail.com',None,np.nan,'anonymoous@gmail.com','Na'],
         # 'age':['33','55','63','36',None,None,'missing']}

# %%
#df = pd.DataFrame(people)

# %%
#df

# %%
#df.dropna()#by default it has these parameters(df.dropna(axis='index',how='any'))
#df.dropna(axis='index',how='any')#here index is meant for rows and for columns it is columns,
#how='any' is even if one NAN value is present it removes and to remove all NAN values keep it as 'all'
#df.dropna(axis='index',how='any',subset = ['last','email'])#subset help us to remove the 
#values based on filter applied on columns, here even if one NAN value is present in any
#of the subset columns they will be removed

# %%
#df.replace('Na',np.nan,inplace=True)
#df.replace('missing',np.nan,inplace=True)
#df.replace('None',np.nan,inplace=True)

# %%
#mean = df['age'].mean()
#df.fillna('m')#to fill the missing values with something else

# %%
#df.dtypes

# %%
#df['age']=df['age'].astype(float)#since there are NAN values present in age column you can't 
#convert them to integer as NAN values are by default float values if you want to convert to integers then
#replace those NAN values with some integers
#df.dtypes

# %%
#df['age'].mean()

# %%
df['YearsCode'].unique()# to find the unique values present in the data if any.
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 'Less than 1 year', '30', '9', '26', '40', '19',
#        '15', '20', '28', '25', '1', '22', '11', '33', '50', '41', '18',
#        '34', '24', '23', '42', '27', '21', '36', '32', '39', '38', '31',
#        '37', 'More than 50 years', '29', '44', '45', '48', '46', '43',
#        '47', '49'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year',0,inplace=True)
df['YearsCode'].replace('More than 50 years',50,inplace=True)

# %%
df['YearsCode'] = df["YearsCode"].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# 11.660681389160544

# %% [markdown]
# ### Datetime conversion

# %%
d_parser = lambda x:pd.datetime.strptime(x,'%Y-%m-%d %I-%p')
df1 = pd.read_csv('datetime.csv',parse_dates=['Date'],date_parser=d_parser)#in order to  directly convert
#the datetime string to date_time we use this method
# Out:
# <ipython-input-55-35eb00defc04>:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   d_parser = lambda x:pd.datetime.strptime(x,'%Y-%m-%d %I-%p')

# %%
df1
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#                     DayOfWeek
# Date
# 2020-03-13 20:00:00     March
# ...

# %%
#df1.loc[2,'Date'].month_name()
#df1.loc[0,'Date'].day_name()
df1['Date'].dt.day_name()
#df1['Date'].dt.month_name()
#df1['DayOfWeek'] = df1['Date'].dt.month_name()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\DSsoftwares\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-98-d04275df5b72> in <module>
#       1 #df1.loc[2,'Date'].month_name()
# ...

# %%
#df1['Date']=pd.to_datetime(df1['Date'],format='%Y-%m-%d %I-%p')#if the date column is not converted to datetime format we
#use this method also that the format series is in Date column format
#df1['Date']=pd.to_datetime(df1['Date'])#if Date column has directly in datetime format no need to convert the format to the 
#required format

# %%
df1['Date'].min()
df1['Date'].max()#gives latest date
df1['Date'].max()-df1['Date'].min()#gives the time span
# Out:
# Timedelta('986 days 09:00:00')

# %% [markdown]
# ### filtering the data based on particular date

# %%
filt = (df1['Date']>'2019') & (df1['Date']<'2020')
filt = (df1['Date']>=pd.to_datetime('2019-12-31 23:00:00')) & (df1['Date']<=pd.to_datetime('2020-01-01 00:00:00'))

#df1.loc[filt]

# %%
df1.set_index('Date',inplace=True)

# %%
df1
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#                     DayOfWeek
# Date
# 2020-03-13 20:00:00     March
# ...

# %%
df1['2020-01':'2020-02']['Close'].mean()
# Out:
# 195.16559027777814

# %%
df1['2020-01-01']['High'].max()
# Out:
# 132.68

# %%
df1['High'].resample('D').mean()
#getting all the values obtained on all days
highs = df1['High'].resample('D').max()#sampling the data based on days, you can similarly sample the data basedd on other parameters
# for which you can get the codes from web
highs['2020-01-01']#out of all the values obtained on all days getting the data of 2020-01-01
# Out:
# 132.68

# %%
df1.resample('W').agg({'Close':'mean','High':'max','Low':'min','Volume':'sum'})
# Out:
#                  Close    High     Low        Volume
# Date
# 2017-07-02  268.202162  293.73  253.23  8.084631e+07
# 2017-07-09  261.062083  285.00  231.25  2.246746e+08
# 2017-07-16  195.698393  240.33  130.26  5.017750e+08
# 2017-07-23  212.783750  249.40  153.25  7.221637e+08
# 2017-07-30  203.309524  229.99  178.03  2.657305e+08
# ...                ...     ...     ...           ...
# 2020-02-16  255.198452  290.00  216.31  3.912867e+08
# 2020-02-23  265.321905  287.13  242.36  3.067838e+08
# 2020-03-01  236.373988  278.13  209.26  3.693920e+08
# 2020-03-08  229.817619  253.01  196.00  2.736569e+08
# 2020-03-15  176.332821  208.65   90.00  4.983998e+08
#
# [142 rows x 4 columns]

# %%
#df1.resample('W').mean()

# %%
filt =(df['Country']=='India')

# %%
india_df = df.loc[filt]

# %%
india_df
# Out:
#       Country  Respondent                              MainBranch Hobbyist  \
# 7       India           8             I code primarily as a hobby      Yes
# 9       India          10          I am a developer by profession      Yes
# 14      India          15  I am a student who is learning to code      Yes
# 49      India          50          I am a developer by profession      Yes
# 64      India          65          I am a developer by profession      Yes
# ...       ...         ...                                     ...      ...
# 88808   India       77339                                     NaN      Yes
# 88825   India       79795                                     NaN      Yes
# 88852   India       83862                                     NaN      Yes
# 88853   India       84299                                     NaN      Yes
# 88864   India       86012                                     NaN      Yes
#
#                                              OpenSourcer  \
# ...

# %%
india_df.to_csv('modified.csv')

# %%
india_df.to_csv('modified.tsv',sep='\t')#if sep is not mentioned by default it takes ',' as seperator

# %%
india_df.to_excel('modified.xlsx')

# %%
test = pd.read_excel('modified.xlsx',index_col='Respondent')

# %%
test.head()
# Out:
#             Unnamed: 0 Country                              MainBranch  \
# Respondent
# 8                    7   India             I code primarily as a hobby
# 10                   9   India          I am a developer by profession
# 15                  14   India  I am a student who is learning to code
# 50                  49   India          I am a developer by profession
# 65                  64   India          I am a developer by profession
#
#            Hobbyist                 OpenSourcer  \
# Respondent
# 8               Yes     Less than once per year
# 10              Yes  Once a month or more often
# 15              Yes                       Never
# 50              Yes  Once a month or more often
# 65              Yes                       Never
#
#                                                    OpenSource  \
# Respondent
# 8           OSS is, on average, of HIGHER quality than pro...
# 10          OSS is, on average, of HIGHER quality than pro...
# ...

# %%
india_df.to_json('modified.json',orient='records',lines=True)

# %%
test = pd.read_json('modified.json',orient='record',lines=True)

# %%
test.head()
# Out:
#   Country  Respondent                              MainBranch Hobbyist  \
# 0   India           8             I code primarily as a hobby      Yes
# 1   India          10          I am a developer by profession      Yes
# 2   India          15  I am a student who is learning to code      Yes
# 3   India          50          I am a developer by profession      Yes
# 4   India          65          I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0     Less than once per year
# 1  Once a month or more often
# 2                       Never
# 3  Once a month or more often
# 4                       Never
#
#                                           OpenSource  \
# 0  OSS is, on average, of HIGHER quality than pro...
# 1  OSS is, on average, of HIGHER quality than pro...
# 2  OSS is, on average, of HIGHER quality than pro...
# 3  OSS is, on average, of LOWER quality than prop...
# 4                                               None
#
# ...
